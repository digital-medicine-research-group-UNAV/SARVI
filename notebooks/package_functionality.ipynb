# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [3]</a>'.</span>

# %%
import torch

from MrDoc.models import PipelineContext, LLMConfig
from MrDoc.config import paths
from MrDoc.main import run
# Out:
# [2026-04-30 09:08:45] INFO SentenceTransformer.py:219: Use pytorch device_name: cuda:0
# [2026-04-30 09:08:45] INFO SentenceTransformer.py:227: Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Some weights of XLMRobertaModel were not initialized from the model checkpoint at IIC/RigoBERTa-Clinical and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
llm_config = LLMConfig(
    service="vllm",
    model="openai/gpt-oss-20b",
    device="cuda" if torch.cuda.is_available() else "cpu"
)

ctx = PipelineContext(
    ussage="deterministic",
    folder_and_archive_name="CodiEsp",
    llm_config=llm_config,
    paths=paths,
    cie_10_version="2026",
    json_parse=False
)

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
tarea = "docx_to_jsons"
# tarea = "jsons_to_xlsx"

modo = "sync"
# modo = "async"

results = run(ctx, tarea, ctx.ussage, modo, ctx.folder_and_archive_name)
# Out:
# Ejecutando docx_to_jsons // modo sync // ussage deterministic...
# INFO 04-30 09:08:56 [utils.py:261] non-default args: {'enable_prefix_caching': True, 'gpu_memory_utilization': 0.6, 'disable_log_stats': True, 'limit_mm_per_prompt': {'image': {'count': 0}, 'video': {'count': 0}}, 'enable_sleep_mode': True, 'model': 'openai/gpt-oss-20b'}
# WARNING 04-30 09:08:56 [arg_utils.py:1220] The global random seed is set to 0. Since VLLM_ENABLE_V1_MULTIPROCESSING is set to False, this may affect the random state of the Python process that launched vLLM.
# INFO 04-30 09:08:57 [model.py:541] Resolved architecture: GptOssForCausalLM
# Parse safetensors files:   0%|          | 0/3 [00:00<?, ?it/s]
# INFO 04-30 09:08:58 [model.py:1561] Using max model len 131072
# INFO 04-30 09:08:59 [scheduler.py:226] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 04-30 09:08:59 [config.py:314] Overriding max cuda graph capture size to 1024 for performance.
# ...

# %%
results[-1]

# %%
import pickle
from pathlib import Path

output_path = Path(ctx.paths.docs_dir / "results.pkl")

with open(output_path, "wb") as f:
    pickle.dump(results, f)

# %%
# import pickle
# from pathlib import Path

# input_path = Path("results.pkl")

# with open(input_path, "rb") as f:
#     results = pickle.load(f)

# (
#     (df_final_ner, df_final_ner_corrected),
#     (df_data_full, df_data_diags, tmp),
#     entities_correction_decision,
#     (
#         final_results,
#         results_yes_hd,
#         results_no_hd,
#         flattened_predictions_yes_hs,
#         flattened_predictions_no_hs,
#     ),
# ) = results

# %%
from MrDoc.main import terminate_process
terminate_process()
