# %%
import ftfy
import pandas as pd
from MrDoc.services.common import plot_histogram_with_binary_data, plot_true_evolution, show_scrollable
from MrDoc.config import paths

# %%
datos_gptoss = pd.read_excel(paths.data_output / "df_Full_CUN_V0.2_FINAL.xlsx")
# datos_gptoss_medgemma = pd.read_excel(paths.data_output / "df_OLLAMA_GPTOSS_20B_PLUS_MEDGEMMA_FINAL.xlsx")

datos_gptoss = datos_gptoss.map(lambda x: ftfy.fix_text(x) if isinstance(x, str) else x)
# datos_gptoss_medgemma = datos_gptoss_medgemma.map(lambda x: ftfy.fix_text(x) if isinstance(x, str) else x)

# %%
plot_histogram_with_binary_data(df=datos_gptoss, column_name_emb_sim="similarity_predicted_selected_V2", column_name_cie10_sim="tree_5_V2", title="GPT-OSS", y_max=300)
plot_histogram_with_binary_data(df=datos_gptoss, column_name_emb_sim="similarity_predicted_nearest", column_name_cie10_sim="tree_5_V2", title="GPT-OSS", y_max=400)

# %%
# plot_histogram_with_binary_data(df=datos_gptoss_medgemma, column_name_emb_sim="similarity_predicted_selected_V2", column_name_cie10_sim="tree_5_V2", title="GPT-OSS + MEDGEMMA", y_max=110)
# plot_histogram_with_binary_data(df=datos_gptoss_medgemma, column_name_emb_sim="similarity_predicted_nearest", column_name_cie10_sim="tree_5_V2", title="GPT-OSS + MEDGEMMA", y_max=110)

# %%
plot_true_evolution(datos_gptoss, title="Analisis porcentaje de aciertos")
# plot_true_evolution(datos_gptoss_medgemma, title="GPT-OSS + MEDGEMMA")

# %% [markdown]
# # EXTRA

# %% [markdown]
# ## Tree 3 = **TRUE**

# %%
columnas = ["diagnostico_predicted", "CIE10_predicted", "diagnostico_nearest", "CIE10_nearest", "diagnostico_selected", "CIE10_selected", "tree_3"]
# datos_gptoss[(datos_gptoss["tree_1"] == True) & (datos_gptoss["tree_5"] == True)][columnas]
datos_gptoss.loc[[26, 72, 1530]][columnas]
# Out:
#                          diagnostico_predicted CIE10_predicted  \
# 26                                    Obesidad          E66.01
# 72                                   Sobrepeso           E66.3
# 1530  Disminución de los niveles de vitamina D           E55.9
#
#                           diagnostico_nearest CIE10_nearest  \
# 26                  Obesidad, no especificada         E66.9
# 72                                  Sobrepeso         E66.3
# 1530  Carencia de vitamina D, no especificada         E55.9
#
#                          diagnostico_selected CIE10_selected  tree_3
# 26                  Obesidad, no especificada          E66.9    True
# 72                                  Sobrepeso          E66.3    True
# 1530  Carencia de vitamina D, no especificada          E55.9    True

# %% [markdown]
# ## Tree 3 = **FALSE** and Tree 5 = **TRUE**

# %%
columnas = ["diagnostico_predicted", "CIE10_predicted", "diagnostico_nearest", "CIE10_nearest", "diagnostico_selected", "CIE10_selected", "tree_3", "tree_4", "tree_5"]
show_scrollable(datos_gptoss[(datos_gptoss["tree_1"] == False) & (datos_gptoss["tree_5_V2"] == True) & (datos_gptoss["similarity_predicted_selected"] < 0.2)][columnas])
# Out:
#     <div style="max-height:400px; overflow:auto; border:1px solid #ddd; border-radius:6px;">
#         <table class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>diagnostico_predicted</th>
#       <th>CIE10_predicted</th>
#       <th>diagnostico_nearest</th>
#       <th>CIE10_nearest</th>
#       <th>diagnostico_selected</th>
#       <th>CIE10_selected</th>
#       <th>tree_3</th>
#       <th>tree_4</th>
#       <th>tree_5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19</th>
#       <td>Cáncer de páncreas (familiar)</td>
#       <td>C25.9</td>
#       <td>Enfermedad de la neurona motora familiar</td>
#       <td>G12.24</td>
#       <td>Neoplasia maligna de páncreas, no especificada</td>
#       <td>C25.9</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>Abuelos paternos IAM en la década de los 60 años</td>
#       <td>I21.9</td>
#       <td>Agenesia y aplasia de útero</td>
#       <td>Q51.0</td>
#       <td>Infarto agudo de miocardio, no especificado</td>
#       <td>I21.9</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>abuelo varios ACV, fallecido a los 80 años</td>
#       <td>I63.9</td>
#       <td>Estado de alergia a suero y vacunas</td>
#       <td>Z88.7</td>
#       <td>Infarto cerebral, no especificado</td>
#       <td>I63.9</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>Litiasis renal milimétrica</td>
#       <td>N20.0</td>
#       <td>Displasia renal</td>
#       <td>Q61.4</td>
#       <td>Cálculo del riñón</td>
#       <td>N20.0</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>Masa ovárico/anexial</td>
#       <td>N80.9</td>
#       <td>Agresión por humo, fuego y llamas, secuela</td>
#       <td>X97.XXXS</td>
#       <td>Endometriosis, no especificada</td>
#       <td>N80.9</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>HTA (familiar)</td>
#       <td>I10</td>
#       <td>Enfermedad de la neurona motora familiar</td>
#       <td>G12.24</td>
#       <td>Hipertensión esencial (primaria)</td>
#       <td>I10</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>145</th>
#       <td>Hipercifosis dorsal</td>
#       <td>M43.0</td>
#       <td>Hipercalciuria</td>
#       <td>R82.994</td>
#       <td>Otras dorsopatías deformantes especificadas, región torácica</td>
#       <td>M43.8X4</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>192</th>
#       <td>Cáncer de próstata (familiar)</td>
#       <td>C61.9</td>
#       <td>Enfermedad de la neurona motora familiar</td>
#       <td>G12.24</td>
#       <td>Atrofia muscular espinal, no especificada</td>
#       <td>G12.9</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>213</th>
#       <td>Insuficiencia aórtica moderada</td>
#       <td>I34.0</td>
#       <td>Discapacidad intelectual moderada</td>
#       <td>F71</td>
#       <td>Insuficiencia (de la válvula) mitral no reumática</td>
#       <td>I34.0</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>249</th>
#       <td>HTA</td>
#       <td>I10</td>
#       <td>Hirsutismo</td>
#       <td>L68.0</td>
#       <td>Hipertensión esencial (primaria)</td>
#       <td>I10</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>319</th>
#       <td>Nódulo mamario izquierdo</td>
#       <td>D23.0</td>
#       <td>Queratomalacia, ojo izquierdo</td>
#       <td>H18.442</td>
#       <td>Otras neoplasias benignas de piel de labio</td>
#       <td>D23.0</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>326</th>
#       <td>ACV (línea paterna)</td>
#       <td>I63.9</td>
#       <td>Coxa magna, cadera izquierda</td>
#       <td>M91.42</td>
#       <td>Infarto cerebral, no especificado</td>
#       <td>I63.9</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>334</th>
#       <td>Glucosa en el límite alto</td>
#       <td>R73.0</td>
#       <td>Glucemia anormal que complica el parto</td>
#       <td>O99.814</td>
#       <td>Prediabetes</td>
#       <td>R73.03</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>338</th>
#       <td>Hiperplasia tiroidea</td>
#       <td>D68.1</td>
#       <td>Hiperplasia de apéndice</td>
#       <td>K38.0</td>
#       <td>Enfermedad de apéndice, no especificada</td>
#       <td>K38.9</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>350</th>
#       <td>EPOC (COPD)</td>
#       <td>J44.9</td>
#       <td>Espermatocele de epidídimo, no especificado</td>
#       <td>N43.40</td>
#       <td>Enfermedad pulmonar obstructiva crónica, no especificada</td>
#       <td>J44.9</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>431</th>
#       <td>Choque subacromial</td>
#       <td>M75.2</td>
#       <td>Choque contra un mueble, secuela</td>
#       <td>W22.03XS</td>
#       <td>Síndrome de pinzamiento de hombro no especificado</td>
#       <td>M75.40</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>448</th>
#       <td>Gonartrosis</td>
#       <td>M17.9</td>
#       <td>Artritis gonocócica</td>
#       <td>A54.42</td>
#       <td>Artrosis de rodilla no especificada</td>
#       <td>M17.9</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>455</th>
#       <td>HTA</td>
#       <td>I10</td>
#       <td>Hirsutismo</td>
#       <td>L68.0</td>
#       <td>Hipertensión esencial (primaria)</td>
#       <td>I10</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>520</th>
#       <td>HTA</td>
#       <td>I10</td>
#       <td>Hirsutismo</td>
#       <td>L68.0</td>
#       <td>Hipertensión esencial (primaria)</td>
#       <td>I10</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>537</th>
#       <td>HTA</td>
#       <td>I10</td>
#       <td>Hirsutismo</td>
#       <td>L68.0</td>
#       <td>Hipertensión esencial (primaria)</td>
#       <td>I10</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>583</th>
#       <td>Disminución de los valores de HDL</td>
#       <td>E78.0</td>
#       <td>Hallazgo de drogas psicotrópicas en sangre</td>
#       <td>R78.5</td>
#       <td>Hiperlipidemia mixta</td>
#       <td>E78.2</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>585</th>
#       <td>Niveles de LDL por encima de lo deseable</td>
#       <td>E78.0</td>
#       <td>Niveles anormales de enzimas en suero, no especificados</td>
#       <td>R74.9</td>
#       <td>Hipercolesterolemia pura, no especificada</td>
#       <td>E78.00</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>602</th>
#       <td>Leucopenia</td>
#       <td>D71.0</td>
#       <td>Leucoplasia del pene</td>
#       <td>N48.0</td>
#       <td>Trastorno del pene, no especificado</td>
#       <td>N48.9</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>614</th>
#       <td>Episodios de deposición explosiva</td>
#       <td>R19.4</td>
#       <td>Otros episodios depresivos especificados</td>
#       <td>F32.89</td>
#       <td>Otras alteraciones fecales</td>
#       <td>R19.5</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>626</th>
#       <td>Lesiones focales hepáticas sugestivas de hiperplasia nodular focal</td>
#       <td>D34.5</td>
#       <td>Hiperacusia, bilateral</td>
#       <td>H93.233</td>
#       <td>Trastorno no especificado del oído, oído no especificado</td>
#       <td>H93.90</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <t

# %%
columnas = ["diagnostico_predicted", "CIE10_predicted", "diagnostico_nearest", "CIE10_nearest", "diagnostico_selected", "CIE10_selected", "tree_3", "tree_4", "tree_5"]
# datos_gptoss[(datos_gptoss["tree_1"] == False) & (datos_gptoss["tree_5_V2"] == True) & (datos_gptoss["similarity_predicted_selected"] < 0.2)][columnas]
datos_gptoss.loc[[2, 242, 1010]][columnas]
# Out:
#          diagnostico_predicted CIE10_predicted        diagnostico_nearest  \
# 2     Bacteriuria asintomática           N32.0                Bacteriuria
# 242           Melanoma in situ           C43.9  Melanoma in situ de labio
# 1010           EPOC (familiar)           J44.9    Insomnio familiar fatal
#
#      CIE10_nearest                               diagnostico_selected  \
# 2           R82.71                                        Bacteriuria
# 242          D03.0     Melanoma in situ, localización no especificada
# 1010        A81.83  Enfermedad pulmonar obstructiva crónica, no es...
#
#      CIE10_selected  tree_3  tree_4  tree_5
# 2            R82.71   False    True    True
# 242           D03.9   False    True    True
# 1010          J44.9   False   False    True

# %% [markdown]
# ## Tree 5 = **TRUE**

# %%
columnas = ["diagnostico_predicted", "CIE10_predicted", "diagnostico_nearest", "CIE10_nearest", "diagnostico_selected", "CIE10_selected", "tree_4", "tree_5"]
# datos_gptoss[(datos_gptoss["tree_4"] == False) & (datos_gptoss["tree_5"] == True)][columnas]
datos_gptoss.loc[[499, 635, 709]][columnas]
# Out:
#                                  diagnostico_predicted CIE10_predicted  \
# 499                                           Ansiedad           F41.9
# 635  Traumatismo craneoencefálico con pérdida de co...           S06.2
# 709                         Alergia a pólenes de olivo           J30.1
#
#                                    diagnostico_nearest CIE10_nearest  \
# 499                                        Anencefalia         Q00.0
# 635  Traumatismo de nervios craneales no especifica...      S04.9XXS
# 709                     Estado de alergia a anestésico         Z88.4
#
#                                   diagnostico_selected CIE10_selected  tree_4  \
# 499             Trastorno de ansiedad, no especificado          F41.9   False
# 635  Lesión cerebral traumática difusa con pérdida ...       S06.2X9A   False
# 709                    Rinitis alérgica debida a polen          J30.1   False
#
#      tree_5
# 499    True
# 635    True
# 709    True

# %% [markdown]
# ## Tree 5 V2 = **TRUE**

# %%
columnas = ["diagnostico_predicted", "CIE10_predicted", "diagnostico_selected", "CIE10_selected", "diagnostico_selected_V2", "CIE10_selected_V2", "tree_5", "tree_5_V2"]
# datos_gptoss[(datos_gptoss["tree_5_V2"] == True) & (datos_gptoss["tree_5"] == False)][columnas]
datos_gptoss.loc[[92, 166, 681, 2063]][columnas]
# Out:
#            diagnostico_predicted CIE10_predicted  \
# 92                          asma         J45.909
# 166   Dudosa pancreatitis (1994)           K85.9
# 681                Ictus (padre)           I63.9
# 2063             Tabaquismo leve           F17.2
#
#                                    diagnostico_selected CIE10_selected  \
# 92             Asma no especificada, sin complicaciones        J45.909
# 166   Pancreatitis aguda sin necrosis ni infección, ...         K85.90
# 681                   Infarto cerebral, no especificado          I63.9
# 2063  Dependencia de nicotina, cigarrillos, sin comp...        F17.210
#
#                          diagnostico_selected_V2 CIE10_selected_V2  tree_5  \
# 92      Asma no especificada, sin complicaciones           J45.909   False
# 166   Enfermedades de páncreas, no especificadas             K86.9   False
# 681                   Historia familiar de ictus             Z82.3   False
# 2063                           Consumo de tabaco             Z72.0   False
#
#       tree_5_V2
# 92         True
# 166        True
# 681        True
# 2063       True

# %% [markdown]
# ## Tree 5 V2 = **FALSE**

# %%
columnas = ["diagnostico_predicted", "CIE10_predicted", "diagnostico_selected", "CIE10_selected", "diagnostico_selected_V2", "CIE10_selected_V2", "tree_5_V2"]
datos_gptoss[(datos_gptoss["tree_5_V2"] == False)][columnas]
# datos_gptoss.loc[[73, 91, 516, 523]][columnas]
# Out:
#                                   diagnostico_predicted CIE10_predicted  \
# 1                                          Sedentarismo           Z73.1
# 3                                        Adenoidectomía           Z87.1
# 14    Hígado de tamaño normal y contornos lisos con ...           Z00.0
# 19          Colonoscopia en 2019, sin anomalías mucosas          Z87.89
# 20                       Hernia lumbar (última en 2004)           M42.0
# ...                                                 ...             ...
# 5427                          Intolerancia a Rabeprazol           Z79.1
# 5440    Probable enfermedad por reflujo gastroesofágico           K21.9
# 5464  Insuficiencia respiratoria nasal secundaria a ...           J34.1
# 5476                              Alergia a terramicina           T78.2
# 5478                                       Ototubaritis           H66.0
#
#                                    diagnostico_selected CIE10_selected  \
# 1                              Falta de descanso y ocio          Z73.2
# 3     Historia personal de otras afecciones especifi...        Z87.898
# 14    Contacto para reconocimiento médico general de...         Z00.00
# 19    Historia personal de otras afecciones especifi...        Z87.898
# 20    Osteocondrosis del adulto de columna vertebral...         M42.16
# ...                                                 ...            ...
# 5427  Otra terapia prolongada (actual) con medicamentos        Z79.899
# 5440  Enfermedad por reflujo gastroesofágico con eso...         K21.00
# 5464                             Tabique nasal desviado          J34.2
# 5476          Alergia no especificada, contacto inicial       T78.40XA
# 5478  Otitis media supurativa aguda sin rotura espon...        H66.001
#
#                                 diagnostico_selected_V2 CIE10_selected_V2  \
# 1                              Falta de descanso y ocio             Z73.2
# 3     Historia personal de otras afecciones especifi...           Z87.898
# 14    Contacto para reconocimiento médico general de...            Z00.00
# 19    Lesión primaria por onda expansiva de colon as...          S36.510A
# 20    Otros desplazamientos de disco intervertebral,...            M51.26
# ...                                                 ...               ...
# 5427  Otra terapia prolongada (actual) con medicamentos           Z79.899
# 5440  Enfermedad por reflujo gastroesofágico con eso...            K21.00
# 5464                             Tabique nasal desviado             J34.2
# 5476          Alergia no especificada, contacto inicial          T78.40XA
# 5478  Otitis media supurativa aguda sin rotura espon...           H66.001
#
#       tree_5_V2
# 1         False
# 3         False
# 14        False
# 19        False
# 20        False
# ...         ...
# 5427      False
# 5440      False
# 5464      False
# 5476      False
# 5478      False
#
# [537 rows x 7 columns]
